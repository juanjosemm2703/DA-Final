# %% [markdown]
# # Final Assignment
# ##  Name: Juan Martinez, StudentID: S5280075, email: juan.martinez@griffithuni.edu.au
# ##  Name: Adriana Lopez Solano, StudentID: S5325946, email: Adriana.lopezsolano@grifith.edu.au

# %%
pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /opt/anaconda3/envs/mypandasenv/lib/python3.12/site-packages (0.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import string
import numpy as np
import pandas as pd
from IPython.core.display import display, HTML
from tabulate import tabulate
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
# Increase the width of the notebook for displaying DataFrames
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/2513826476.py:5: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:75% !important; }</style>

# %% [markdown]
# # Part 1 - Data Preparation and Preprocessing. (15 Marks)

# %% [markdown]
# ## 1. Describe the dataset. (8 Marks)

# %% [markdown]
# ### Load the dataset. Describe the dataset (e.g.: type of column, value range). (1 Mark)

# %%
df = pd.read_csv('data.csv')
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/1507164070.py:1: DtypeWarning: Columns (0,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318477 entries, 0 to 318476
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Id                 318477 non-null  object
#  1   Title              318477 non-null  object
#  2   Company            306473 non-null  object
#  3   Date               318477 non-null  object
#  4   Location           197229 non-null  object
#  5   Area               122658 non-null  object
#  6   Classification     197229 non-null  object
#  7   SubClassification  197229 non-null  object
#  8   Requirement        318470 non-null  object
#  9   FullDescription    302302 non-null  object
#  10  LowestSalary       318477 non-null  int64
#  11  HighestSalary      318477 non-null  int64
#  12  JobType            302379 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 31.6+ MB

# %%
_ids = df['Id'].nunique()
_titles = df['Title'].nunique()
_companies = df['Company'].nunique()
_dates = df['Date'].nunique()
_locations = df['Location'].nunique()
_area = df['Area'].nunique()
_classes = df['Classification'].nunique()
_subclasses = df['SubClassification'].nunique()
_requirements = df['Requirement'].nunique()
_description = df['FullDescription'].nunique()
_lowest_salary = df['LowestSalary'].nunique()
_highest_salary = df['HighestSalary'].nunique()
_job_type = df['JobType'].nunique()

data=[
    ['Ids', _ids],
    ['Titles', _titles],
    ['Companies', _companies],
    ['Dates', _dates],
    ['Locations', _locations],
    ['Area', _area],
    ['Classification', _classes],
    ['SubClassification', _subclasses],
    ['Requirement', _requirements],
    ['FullDescription', _description],
    ['LowestSalary', _lowest_salary],
    ['HighestSalary', _highest_salary],
    ['JobType', _job_type]
]
col_headers = ['Attribute', 'No. of Variations']
print(tabulate(data, headers=col_headers, tablefmt='grid'))
# Out:
# +-------------------+---------------------+
# | Attribute         |   No. of Variations |
# +===================+=====================+
# | Ids               |              318477 |
# +-------------------+---------------------+
# | Titles            |              168065 |
# +-------------------+---------------------+
# | Companies         |               40628 |
# +-------------------+---------------------+
# | Dates             |                 163 |
# +-------------------+---------------------+
# | Locations         |                  65 |
# +-------------------+---------------------+
# | Area              |                  19 |
# +-------------------+---------------------+
# | Classification    |                  30 |
# +-------------------+---------------------+
# | SubClassification |                 338 |
# +-------------------+---------------------+
# | Requirement       |              234287 |
# +-------------------+---------------------+
# | FullDescription   |              250901 |
# +-------------------+---------------------+
# | LowestSalary      |                  11 |
# +-------------------+---------------------+
# | HighestSalary     |                  11 |
# +-------------------+---------------------+
# | JobType           |                   4 |
# +-------------------+---------------------+

# %% [markdown]
# ### How many records are there in the dataset? (1 Mark)

# %%
df.head()
# Out:
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# 1    Richmond & Hawkesbury                          NaN
# 2                 Brisbane          CBD & Inner Suburbs
# 3  Gosford & Central Coast                          NaN
# 4                   Sydney        Ryde & Macquarie Park
#
#                    Classification  SubClassification  \
# 0      Retail & Consumer Products  Retail Assistants
# 1      Retail & Consumer Products  Retail Assistants
# 2      Retail & Consumer Products  Retail Assistants
# 3      Retail & Consumer Products  Retail Assistants
# 4  Call Centre & Customer Service    Sales - Inbound
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
# 3  Bring it on - do you love the great outdoors a...             NaN
# 4  We are seeking highly articulate, enthusiastic...             NaN
#
#    LowestSalary  HighestSalary JobType
# 0             0             30     NaN
# 1             0             30     NaN
# 2             0             30     NaN
# 3             0             30     NaN
# 4             0             30     NaN

# %%
print("The Dataset consists of: ", df.shape[0], " rows and ", df.shape[1], " columns.")
# Out:
# The Dataset consists of:  318477  rows and  13  columns.

# %% [markdown]
# ### Which period does it cover? How many different dates have job postings? (1 Mark)

# %%
dates = df.sort_values('Date')['Date'].dropna().unique()
start_date = pd.to_datetime(dates[0])
start_date = start_date.date()
end_date = pd.to_datetime(dates[len(dates)-1])
end_date = end_date.date()

print("The dataset spans from", start_date, "to", end_date)
print("The dataset has ", _dates, " unique dates.")
# Out:
# The dataset spans from 2018-10-01 to 2019-03-13
# The dataset has  163  unique dates.

# %% [markdown]
# ### How many locations does the dataset have? Which location has the most job postings? (1 Mark)

# %%
location_counts = df['Location'].value_counts()
df_locations = pd.DataFrame(location_counts)
most_common_location = location_counts.idxmax()
df_locations.reset_index(inplace=True)
print("The dataset has ", _locations, " unique locations.")
print("The location with the most job listings is:", most_common_location)
# Out:
# The dataset has  65  unique locations.
# The location with the most job listings is: Sydney

# %%
#Get top 10 big cities
locationTop10Df = df_locations[:10].copy()
#others
new_row = pd.DataFrame(data = {
    'Location' : ['Others'],
    'count' : [df_locations["count"][10:].sum()]
})
locationTop10Df = pd.concat([locationTop10Df, new_row],sort=False)
locationTop10Df.index = locationTop10Df['Location']

# %%
plt.figure(figsize=(10,10))
plt.title('Market share of sectors')
rgba = plt.cm.inferno_r(np.linspace(0, 0.6, len(locationTop10Df)))
plt.pie(
    locationTop10Df['count'],
     labels=locationTop10Df['Location'],     
     colors= rgba,
      autopct=lambda pct: f'{pct:.0f}%' if pct >= 2 else '',)
plt.show()

# %% [markdown]
# ### How many job sectors(job classifications) are there in the dataset? List the name of each sector and its’ total of job postings. (1 Mark)

# %%
classification_counts = df['Classification'].value_counts()
classification_counts
# Out:
# Classification
# Information & Communication Technology    22796
# Trades & Services                         17976
# Healthcare & Medical                      17085
# Hospitality & Tourism                     15523
# Manufacturing, Transport & Logistics      12376
# Administration & Office Support           10020
# Accounting                                 9368
# Education & Training                       9280
# Construction                               8372
# Sales                                      8119
# Retail & Consumer Products                 8041
# Government & Defence                       7443
# Engineering                                6458
# Mining, Resources & Energy                 6288
# Banking & Financial Services               4633
# Community Services & Development           4485
# Legal                                      4237
# Human Resources & Recruitment              4144
# Call Centre & Customer Service             3971
# Marketing & Communications                 3968
# Real Estate & Property                     3614
# Design & Architecture                      1811
# Insurance & Superannuation                 1474
# Consulting & Strategy                      1206
# Sport & Recreation                          984
# Science & Technology                        905
# Farming, Animals & Conservation             882
# CEO & General Management                    844
# Advertising, Arts & Media                   833
# Self Employment                              93
# Name: count, dtype: int64

# %% [markdown]
# ### Choose your favorite job sector (e.g. Information & Communication Technology), how many sub-sectors are there in that sector? List the name of each sub-sector and its’ job posting number (1 Mark)

# %%
df_hcm = df[df['Classification'] == 'Healthcare & Medical']
total_sub = df_hcm['SubClassification'].nunique()
subclassification_counts = df_hcm['SubClassification'].value_counts()
print("There are", total_sub, "sub-sectors in the Healthcare & Medical sector.")
subclassification_counts
# Out:
# There are 33 sub-sectors in the Healthcare & Medical sector.
# SubClassification
# Nursing - Aged Care                                2130
# Physiotherapy, OT & Rehabilitation                 1821
# General Practitioners                              1263
# Psychology, Counselling & Social Work              1123
# Nursing - General Medical & Surgical               1066
# Dental                                             1046
# Other                                               829
# Medical Administration                              812
# Pharmacy                                            808
# Medical Specialists                                 748
# Pharmaceuticals & Medical Devices                   502
# Management                                          496
# Medical Imaging                                     487
# Nursing - A&E, Critical Care & ICU                  446
# Nursing - Psych, Forensic & Correctional Health     433
# Nursing - Management                                374
# Sales                                               347
# Nursing - Community, Maternal & Child Health        341
# Nursing - Theatre & Recovery                        286
# Residents & Registrars                              269
# Nursing - Midwifery, Neo-Natal, SCN & NICU          251
# Clinical/Medical Research                           231
# Speech Therapy                                      173
# Pathology                                           161
# Nursing - Educators & Facilitators                  144
# Optical                                             106
# Natural Therapies & Alternative Medicine            101
# Environmental Services                               79
# Nursing - Paediatric & PICU                          57
# Nursing - High Acuity                                57
# Ambulance/Paramedics                                 49
# Dieticians                                           38
# Chiropractic & Osteopathic                           11
# Name: count, dtype: int64

# %% [markdown]
# ### List the salary ranges and their total of job postings. (1 Mark)

# %%
low = df['LowestSalary'].dropna().unique()
high = df['HighestSalary'].dropna().unique()
assert(len(low)==len(high))

df_salary_ranges = pd.DataFrame({"Low": low, "High":high})
df_salary_ranges['Count'] = df_salary_ranges['Low'].apply(lambda x: len(df[df['LowestSalary']==x]))
print("Total number of job postings:",sum(df_salary_ranges['Count']))
df_salary_ranges
# Out:
# Total number of job postings: 318477
#     Low  High  Count
# 0     0    30  62639
# 1    30    40  23476
# 2    40    50  34436
# 3    50    60  27027
# 4    60    70  28499
# 5    70    80  28712
# 6    80   100  24249
# 7   100   120  27673
# 8   120   150  24514
# 9   150   200  25841
# 10  200   999  11411

# %% [markdown]
# ### List the job types. In each job type, what are the lowest salary and highest salary? (1 Mark)

# %%
grouped = df.groupby('JobType').agg({'LowestSalary': 'min', 'HighestSalary': 'max'})
print(grouped)
# Out:
#                  LowestSalary  HighestSalary
# JobType
# Casual/Vacation             0            999
# Contract/Temp               0            999
# Full Time                   0            999
# Part Time                   0            999

# %% [markdown]
# ## 2. Normalize and clean data. (7 Marks)

# %% [markdown]
# ### The salaries are kept in the dataset as “HighestSalary” and “LowestSalary”. You should calculate the “AverageSalary” for each job. (1 Mark)

# %%
df=df.assign(AverageSalary= lambda row:(row.LowestSalary + row.HighestSalary)/2)
df.head()
# Out:
#          Id                                              Title  \
# 0  37404348                           Casual Stock Replenisher
# 1  37404337                           Casual Stock Replenisher
# 2  37404356  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330                              Team member - Belrose
# 4  37404308  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# 1    Richmond & Hawkesbury                          NaN
# 2                 Brisbane          CBD & Inner Suburbs
# 3  Gosford & Central Coast                          NaN
# 4                   Sydney        Ryde & Macquarie Park
#
#                    Classification  SubClassification  \
# 0      Retail & Consumer Products  Retail Assistants
# 1      Retail & Consumer Products  Retail Assistants
# 2      Retail & Consumer Products  Retail Assistants
# 3      Retail & Consumer Products  Retail Assistants
# 4  Call Centre & Customer Service    Sales - Inbound
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
# 3  Bring it on - do you love the great outdoors a...             NaN
# 4  We are seeking highly articulate, enthusiastic...             NaN
#
#    LowestSalary  HighestSalary JobType  AverageSalary
# 0             0             30     NaN           15.0
# 1             0             30     NaN           15.0
# 2             0             30     NaN           15.0
# 3             0             30     NaN           15.0
# 4             0             30     NaN           15.0

# %%
salaries = df[['LowestSalary', 'HighestSalary', 'AverageSalary']]
salaries.head(10)
# Out:
#    LowestSalary  HighestSalary  AverageSalary
# 0             0             30           15.0
# 1             0             30           15.0
# 2             0             30           15.0
# 3             0             30           15.0
# 4             0             30           15.0
# 5             0             30           15.0
# 6             0             30           15.0
# 7             0             30           15.0
# 8             0             30           15.0
# 9             0             30           15.0

# %% [markdown]
# ### The raw dataset values of the "Id" column had inconsistencies in their representation. The Id values should have 8 number long integers only. Write code to remove unnecessary characters. (1 Mark)

# %%
df["Id"] = df["Id"].replace(to_replace=r'&.*', value='', regex=True)

# %% [markdown]
# ### The "Date" column is represented in a format that contained both date and time information. However, the time is not correct and should be removed. (1 Mark)

# %%
#Your code to clean date
df["Date"] = df["Date"].replace(to_replace=r'T.*', value='', regex=True)

# %% [markdown]
# ### Change type of “Id” column to numeric and change type of “Date” column to DateTime. (1 Mark)

# %%
# Set column "Id" to type int64
df["Id"] = df["Id"].astype(np.int64)

# Set column "Date" to type datetime64[ns]
df["Date"] = pd.to_datetime(df["Date"])

# Data types after data cleaning and conversions
df.dtypes
# Out:
# Id                            int64
# Title                        object
# Company                      object
# Date                 datetime64[ns]
# Location                     object
# Area                         object
# Classification               object
# SubClassification            object
# Requirement                  object
# FullDescription              object
# LowestSalary                  int64
# HighestSalary                 int64
# JobType                      object
# AverageSalary               float64
# dtype: object

# %% [markdown]
# ### Are there any duplicate data in the dataset? Provide the way you find them and your solution to fix it. ** (1.5 Marks)

# %%
# df.drop('Id', axis=1, inplace=True)
duplicate_count = df[df.duplicated()].shape[0]
print("Duplicates found: ", duplicate_count)
no_dates = df.drop('Date', axis=1)
duplicate_count_no_dates = no_dates[no_dates.duplicated()].shape[0]
difference = duplicate_count_no_dates - duplicate_count
print('Additional duplicates found without regard to timestamp: ', difference)
# Out:
# Duplicates found:  108
# Additional duplicates found without regard to timestamp:  43

# %% [markdown]
# ### Check missing data and visualize them in a corresponding chart.** (1.5 Marks)

# %%
def colorize_bar(value, max_value):
    low, high = max_value * 0.2, max_value * 0.66
    if(value <= low):
        return 'navajowhite'
    elif(value >= high):
        return 'darkorange'
    else:
        return 'orange'

    
nulls = df.isnull().sum()
cols = [colorize_bar(n, nulls.max()) for n in nulls]

total_data = [df.shape[0]] * df.shape[1]

plt.figure(figsize=(20,10))
plt.barh(df.columns.values,total_data, color='aliceblue')
plt.barh(df.columns.values,nulls, color=cols)

plt.ylabel('Attribute', size=14)
plt.xlabel('Missing data vs. existing', size=14)
plt.title('Missing data in dataset', size=20)

plt.show();

# %%
#Save the cleaned and preprocessed dataset
df.to_csv("preprocessed_data.csv")

# %% [markdown]
# # Part 2 - Data Understanding. (5 Marks)

# %% [markdown]
# ### Get the salary ranges using “AverageSalary”, the total jobs of each range and display them in the bar chart. (1 Mark)

# %%
#Group by average salary and count the numbers
averageSalaryDf = df.groupby('AverageSalary').count()
averageSalaryDf['AverageSalary'] = (averageSalaryDf.index*1000).astype(float).map('{:,.0f}'.format)
averageSalaryDf['Count'] = averageSalaryDf["Id"]
averageSalaryDf
# Out:
#                   Id  Title  Company   Date  Location   Area  Classification  \
# AverageSalary
# 15.0           62639  62639    59611  62639     38541  24399           38541
# 35.0           23476  23476    22296  23476     16396   9811           16396
# 45.0           34436  34436    32076  34436     21736  13264           21736
# 55.0           27027  27027    25679  27027     16561  10755           16561
# 65.0           28499  28499    27290  28499     18121  11393           18121
# 75.0           28712  28712    27794  28712     17053  10456           17053
# 90.0           24249  24249    23625  24249     12701   7562           12701
# 110.0          27673  27673    27150  27673     17137  10575           17137
# 135.0          24514  24514    24165  24514     14701   9481           14701
# 175.0          25841  25841    25511  25841     15802   9916           15802
# 599.5          11411  11411    11276  11411      8480   5046            8480
#
#                SubClassification  Requirement  FullDescription  LowestSalary  \
# AverageSalary
# 15.0                       38541        62637            56065         62639
# 35.0                       16396        23476            22092         23476
# 45.0                       21736        34435            33580         34436
# 55.0                       16561        27026            26206         27027
# 65.0                       18121        28499            27544         28499
# 75.0                       17053        28712            27670         28712
# 90.0                       12701        24248            23587         24249
# 110.0                      17137        27671            26682         27673
# 135.0                      14701        24514            23610         24514
# 175.0                      15802        25841            24508         25841
# 599.5                       8480        11411            10758         11411
#
#                HighestSalary  JobType AverageSalary  Count
# AverageSalary
# 15.0                   62639    56080        15,000  62639
# 35.0                   23476    22094        35,000  23476
# 45.0                   34436    33585        45,000  34436
# 55.0                   27027    26222        55,000  27027
# 65.0                   28499    27566        65,000  28499
# 75.0                   28712    27674        75,000  28712
# 90.0                   24249    23590        90,000  24249
# 110.0                  27673    26683       110,000  27673
# 135.0                  24514    23612       135,000  24514
# 175.0                  25841    24513       175,000  25841
# 599.5                  11411    10760       599,500  11411

# %% [markdown]
# #### Bar chart to display the correlations between “AverageSalary” and the total jobs of each range (2 marks)

# %%
sns.set_style("whitegrid")

rgba = plt.cm.inferno_r(np.linspace(0, 0.7, len(averageSalaryDf)))
rank = averageSalaryDf['Count'].argsort().argsort() 
sns.barplot(data=averageSalaryDf, x='AverageSalary', y='Count', palette=rgba, hue='AverageSalary', legend=False)
plt.title('Job distribution by average salary ')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/1882112602.py:5: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(data=averageSalaryDf, x='AverageSalary', y='Count', palette=rgba, hue='AverageSalary', legend=False)

# %% [markdown]
# ### Display the list of job types and the number of jobs of each type using pie chart. (1 Mark)

# %%
jobTypeDf = df.groupby('JobType').count()
jobTypeDf['Count'] = jobTypeDf["Id"]
jobTypeDf['JobType'] = jobTypeDf.index
jobTypeDf
# Out:
#                      Id   Title  Company    Date  Location   Area  \
# JobType
# Casual/Vacation   25355   25355    23872   25355     16285   8751
# Contract/Temp     53906   53906    53085   53906     33962  20878
# Full Time        201225  201225   192847  201225    122142  77946
# Part Time         21893   21893    20906   21893     13347   7862
#
#                  Classification  SubClassification  Requirement  \
# JobType
# Casual/Vacation           16285              16285        25353
# Contract/Temp             33962              33962        53906
# Full Time                122142             122142       201224
# Part Time                 13347              13347        21889
#
#                  FullDescription  LowestSalary  HighestSalary  AverageSalary  \
# JobType
# Casual/Vacation            25342         25355          25355          25355
# Contract/Temp              53901         53906          53906          53906
# Full Time                 201169        201225         201225         201225
# Part Time                  21890         21893          21893          21893
#
#                   Count          JobType
# JobType
# Casual/Vacation   25355  Casual/Vacation
# Contract/Temp     53906    Contract/Temp
# Full Time        201225        Full Time
# Part Time         21893        Part Time

# %%
#Your code here
jobTypeDf = df.groupby('JobType').count()
jobTypeDf['Count'] = jobTypeDf["Id"]
jobTypeDf['JobType'] = jobTypeDf.index
rgba = plt.cm.inferno_r(np.linspace(0, 0.4, len(jobTypeDf)))
plt.figure(figsize=(5,5))
plt.title('Job distribution by job type')
plt.pie(
     jobTypeDf['Count'],
     labels=jobTypeDf['JobType'], 
     colors= rgba,
     autopct='%1.1f%%')

plt.show()

# %% [markdown]
# ### Display the list of job sectors and the number of jobs of each type using horizontal bar chart. (1 Mark)

# %%
#Your code here

ClassificationDf = df[df['Classification'].isna()==False]
ClassificationDf = ClassificationDf.groupby('Classification').count()
ClassificationDf['Classification'] = ClassificationDf.index
ClassificationDf['Count'] = ClassificationDf["Id"]
ClassificationDf.sort_values(by='Count', ascending=False, inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.barplot(
    data=ClassificationDf, 
    x='Count',
    y='Classification',
    color= '#377ead', 
    palette= 'inferno',
    hue='Classification',
    legend=False
)

plt.title('Jobs  and Number of postings by Classification')
plt.xlabel('Number of postings')
plt.show()

# %% [markdown]
# ### Choose your favorite location. Visualize the market share of that location in pie chart. (1 Mark)

# %% [markdown]
# Favourite location: Sydney.

# %%
df_sydney = df[df['Location'] == 'Sydney']
df_sydney = df_sydney.groupby('Classification').count().sort_values(by='Id', ascending=False)
df_sydney['Value'] = df_sydney['Id']
df_sydney['Classification'] = df_sydney.index

df_pie=df_sydney[:22].copy()
new_row = pd.DataFrame(data = {
    'Classification' : ['Others'],
    'Value' : [df_sydney["Value"][22:].sum()]
})

rgba = plt.cm.inferno_r(np.linspace(0, 1, len(df_pie)*2))

df_pie = pd.concat([df_pie, new_row])
df_pie.index = df_pie['Classification']
explode = [0.1-x*0.005 for x in range(len(df_pie))]
plt.figure(figsize=(10,10))
plt.pie(df_pie['Value'], labels = df_pie['Classification'],explode=explode,colors=rgba, wedgeprops = {'linewidth': 3}, autopct='%1.1f%%')
plt.title('Market share of Sydney')
plt.show()

# %% [markdown]
# ### Can you find the salary distribution for the top 30 cities for the number of job postings? Visualize them in the boxplot chart. (1 Mark)

# %%
locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf['Location'] = locationDf.index
locationDf['Count'] = locationDf["Id"]
locationDf.sort_values(by='Count', ascending=False, inplace=True)

# %%
plt.figure(figsize=(12,4))
sns.boxplot(
    data= df,
    x='Location',
    y='LowestSalary',
    order= df.groupby(['Location']).count().reset_index().sort_values(by=['Title'],ascending=False)[:30]['Location'].tolist(),
    palette=sns.color_palette("inferno", n_colors=30),
)
plt.title('Location and the Average Lowest Salary')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/2952094028.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
plt.figure(figsize=(12,4))
sns.boxplot(
    data= df,
    x='Location',
    y='HighestSalary',
    order= df.groupby(['Location']).count().reset_index().sort_values(by=['Title'],ascending=False)[:30]['Location'].tolist(),
    palette=sns.color_palette("inferno", n_colors=30)
)
plt.title('Location and the Average Highest Salary')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/1802310008.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# # Part 3 - Data Analysis and Visualisation (6 mark)

# %% [markdown]
# ## 1. Analyse by comparison (2 mark)

# %% [markdown]
# ### Choose your two favourite cities/locations

# %%
df_brisbane_sidney = df[(df['Location'] == 'Brisbane') | (df['Location'] == 'Sydney')]
df_brisbane = df[df['Location'] == 'Brisbane']
df_sydney = df[df['Location'] == 'Sydney']

# %% [markdown]
# ### Which city has more job? How many jobs each type (casual, fulltime, etc.) are there in each city?

# %%
cities = ['Sydney', 'Brisbane']
map_df = pd.DataFrame({"Location":cities})
map_df['Count'] = map_df['Location'].apply(lambda x: df_brisbane_sidney[df_brisbane_sidney['Location'] == x].shape[0])
sydney_row, brisbane_row = map_df['Location'].apply(lambda x: df_brisbane_sidney[df_brisbane_sidney['Location'] == x].groupby('JobType').count())
sydney_row = sydney_row['Id']
brisbane_row = brisbane_row['Id']
combined_df = pd.concat([sydney_row, brisbane_row], axis=1)
combined_df.columns = ['Sydney', 'Brisbane']
combined_df.reset_index(inplace=True)

fig= plt.figure()
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
sns.barplot(data=map_df, x='Location', y='Count', ax=axes[0])
axes[0].set_title('Job distribution in Sydney and Brisbane')
axes[0].set_ylabel('Number of job postings')
axes[0].set_xlabel('City')

sns.barplot(data=pd.melt(combined_df, id_vars='JobType', var_name='Location', value_name='Count'), x='JobType', y='Count', hue='Location', ax=axes[1])

# Add title and labels
plt.title('Number of Jobs by Type and Location')
plt.xlabel('Job Type')
plt.ylabel('Number of Jobs')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability

# Show the legend
plt.legend(title='Location')

# Show the plot
plt.tight_layout()
plt.show()
# axes[2]= sns.barplot(data=sydney_row, x='JobType', y='Id')

# %% [markdown]
# ### In each city, which are top 5 job sectors? How many jobs are there in each sector?

# %%
def extract_classification(df):
    classification_df = df.groupby('Classification').count().sort_values(by='Id', ascending=False)
    classification_df['Classification'] = classification_df.index     
    classification_df['Count'] = classification_df["Id"] 
    df2 = classification_df[:5].copy()
    new_row = pd.DataFrame(data = {
        'Classification' : ['Others'],
        'Count' : [classification_df["Count"][5:].sum()]
    })

    df2 = pd.concat([df2, new_row])
    df2.index = df2['Classification']
    return df2

brisbane_classification = extract_classification(df_brisbane)
sydney_classification = extract_classification(df_sydney)

print('Brisbane top 5 job sector and total of jobs for each job sector:\n',brisbane_classification['Count'],'\n')

print('Sydney top 5 job sector and total of jobs for each job sector:\n',sydney_classification['Count'])
# Out:
# Brisbane top 5 job sector and total of jobs for each job sector:
#  Classification
# Information & Communication Technology     2768
# Trades & Services                          1993
# Healthcare & Medical                       1824
# Manufacturing, Transport & Logistics       1667
# Hospitality & Tourism                      1335
# Others                                    11879
# Name: Count, dtype: int64
#
# Sydney top 5 job sector and total of jobs for each job sector:
#  Classification
# Information & Communication Technology     9548
# Hospitality & Tourism                      4074
# Trades & Services                          4026
# Accounting                                 4010
# Healthcare & Medical                       3339
# Others                                    35768
# Name: Count, dtype: int64

# %% [markdown]
# ### Visualise the top 5 job sectors in pie chart for each city.

# %%
explode = [0.1-x*0.005 for x in range(len(brisbane_classification))]
rgba = plt.cm.inferno_r(np.linspace(0, 1, len(brisbane_classification)*2))

plt.figure(figsize=(15,5))
plt.subplot(121)
plt.pie(brisbane_classification['Count'], labels= brisbane_classification['Classification'],colors=rgba,explode=explode, wedgeprops = {'linewidth': 3}, autopct='%1.1f%%')
plt.title('Market share of Brisbane')
plt.subplot(122)
plt.pie(sydney_classification['Count'], labels= sydney_classification['Classification'],colors=rgba,explode=explode, wedgeprops = {'linewidth': 3}, autopct='%1.1f%%')
plt.title('Market share of Sydney')
plt.show()

# %% [markdown]
# ### In each city, list the job salary range with the corresponding number of jobs. Which city is more well-paid?

# %%
df_salary_ranges['Brisbane_Count'] = df_salary_ranges['Low'].apply(lambda x: len(df_brisbane[df_brisbane['LowestSalary']==x]))
df_salary_ranges['Sydney_Count'] = df_salary_ranges['Low'].apply(lambda x: len(df_sydney[df_sydney['LowestSalary']==x]))

# %%
data_frame = pd.DataFrame(columns = [f'{x[1]["Low"]} - {x[1]["High"]}' for x in df_salary_ranges.iterrows()] )
data_frame.loc['Brisbane'] = df_salary_ranges['Brisbane_Count'].values
data_frame.loc['Sydney'] = df_salary_ranges['Sydney_Count'].values

data_frame = data_frame.transpose()

fig, ax = plt.subplots(figsize=(15, 8))
x = np.arange(len(data_frame))
bar_width = 0.25
multiplier = 0

for city in data_frame.columns:
    offset = bar_width * multiplier
    rects = ax.bar(x + offset, data_frame[city], bar_width, label=city)
    ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set_ylabel('Number of job postings')
ax.set_title('Job postings by salary range and city')
ax.set_xlabel('Salary range')
ax.set_xticks(x + bar_width, data_frame.index)
ax.legend(loc='upper right', ncols=3)
ax.set_ylim(0, 13000)
plt.show()

# %% [markdown]
# ### List top 5 companies in each city? Which sectors do they belong to?

# %%
def extract_top5(df):
    grouped_data = df.groupby('Company').count().sort_values(by='Id', ascending=False)
    top5 = grouped_data[:5].copy()
    top5.reset_index(inplace=True)
    top5['Sector'] = top5['Company'].apply(lambda x: df[df['Company'] == x]['Classification'].values[0])
    top5['Count'] = top5['Id']
    data = top5[['Company', 'Count', 'Sector']]
    return data

brisbane_top5 = extract_top5(df_brisbane)
sydney_top5 = extract_top5(df_sydney)
brisbane_top5
# Out:
#                         Company  Count                                  Sector
# 0                    Jora Local    314                   Hospitality & Tourism
# 1                        Hudson    267  Information & Communication Technology
# 2     u&u. Recruitment Partners    265                              Accounting
# 3  The University of Queensland    248                    Education & Training
# 4  Programmed Skilled Workforce    210    Manufacturing, Transport & Logistics

# %%
explode = [0.1-x*0.005 for x in range(5)]
rgba = plt.cm.inferno_r(np.linspace(0, 0.5, 5))

plt.figure(figsize=(8,13))
sns.set_style("white")
plt.subplot(211)
sns.barplot(data=brisbane_top5, x='Count', y='Company', palette=rgba, orient='y', hue='Company', legend=False)
plt.title('Top 5 Companies in Brisbane')
plt.xlabel('Number of job postings')
plt.ylabel('Companies')
for index, row in brisbane_top5.iterrows():
    plt.text(row['Count'], index, row['Sector'], ha='left', va='center', fontsize=9)
sns.despine()
plt.subplot(212)
sns.barplot(data=sydney_top5, x='Count', y='Company', palette=rgba, orient='y', hue='Company', legend=False)
plt.title('Top 5 Companies in Sydney')
plt.xlabel('Number of job postings')
plt.ylabel('Companies')
for index, row in sydney_top5.iterrows():
    plt.text(row['Count'], index, row['Sector'], ha='left', va='center', fontsize=9)
sns.despine()
plt.show()
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/987307390.py:7: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(data=brisbane_top5, x='Count', y='Company', palette=rgba, orient='y', hue='Company', legend=False)
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/987307390.py:15: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(data=sydney_top5, x='Count', y='Company', palette=rgba, orient='y', hue='Company', legend=False)

# %% [markdown]
# ### Between 2 cities, which do you think it is better for employees.

# %% [markdown]
# To determine whether Brisbane or Sydney is better for employees, we will consider several factors, including job opportunities, average salaries, cost of living, and quality of life. Additionally, we will account for the population of each city as it affects job market saturation and competition.
#
# 1. Job Opportunities and Average Salaries
# Using the job market data provided, we can compare the number of job postings and average salaries between Brisbane and Sydney.
#
#
#
# ![image.png](attachment:image.png)
#
# 2. Cost of Living
# The cost of living in Sydney is generally higher than in Brisbane. Factors include housing, transportation, and daily expenses.
#
# - Sydney: Sydney is known for its high cost of living, particularly in housing. According to Budget Direct, rent prices in Brisbane are 52.47% lower than in Sydney and consumer prices in Brisbane are 3.29% lower than in Sydney.
# - Brisbane: Brisbane offers a more affordable cost of living with lower housing prices and daily expenses.
#
# 3. Quality of Life
# Quality of life includes factors such as climate, traffic, healthcare, and education.
#
# - Sydney: Sydney is a global city with numerous cultural, recreational, and educational opportunities. However, it also faces challenges such as high traffic congestion and a higher cost of living.
# - Brisbane: Brisbane is known for its pleasant climate, less congestion, and a more relaxed lifestyle. It also offers good healthcare and education facilities.
#
# 4. Population
# - Sydney: Approximately 5.3 million people.
# - Brisbane: Approximately 2.5 million people.
#
# A larger population can mean more job opportunities but also greater competition for those jobs. A smaller population might mean less competition but fewer job opportunities.
#
# ## Analysis and Recommendation
#
# - Job Opportunities and Salaries: Sydney tends to offer more job opportunities and higher average salaries compared to Brisbane. However, this is balanced by a higher cost of living.
# - Cost of Living: Brisbane has a lower cost of living, which can make it more attractive for employees looking for a better balance between income and expenses.
# - Quality of Life: Brisbane offers a more relaxed lifestyle with less congestion and a more affordable living environment. Sydney offers more cultural and educational opportunities but at the cost of higher living expenses and more congestion.
# - Population: Sydney’s larger population means more competition for jobs, whereas Brisbane’s smaller population might offer a better balance between job availability and competition.
#
# ## Conclusion
# Recommendation: Brisbane
#
# For employees, Brisbane may be a better choice considering the lower cost of living, less competition for jobs, and overall better quality of life. While Sydney offers higher average salaries and more job opportunities, the high cost of living and congestion can offset these advantages. Brisbane’s affordability, combined with a reasonable number of job opportunities and a pleasant lifestyle, makes it an attractive option for employees.

# %% [markdown]
# ## 2. Analyse by time. (2 points)

# %% [markdown]
# ### In this part, we will analyse the jobs based on the posting date.

# %%
tqdm.pandas()

temp = df[['Date']].copy() 
temp['DayOfMonth'] = temp['Date'].progress_apply(lambda x: pd.Series(x.day))
temp['DayOfWeek'] = temp['Date'].progress_apply(lambda x: pd.Series(x.dayofweek))
temp['Month'] = temp['Date'].progress_apply(lambda x: pd.Series(x.month))
temp['Week'] = temp['Date'].progress_apply(lambda x: pd.Series(x.week))

days = temp['Date'].progress_apply(lambda x: pd.Series("{}_{}".format(x.day, x.month)))
day_months = days.iloc[:, 0].unique()
unique_day_count = {}

# Get unique days that data was recorded via retrieving day and month of posting
for day in day_months:
    d_m = day.split('_')
    d = int(d_m[0])
    m = int(d_m[1])
    
    if(d in unique_day_count):
        unique_day_count[d] += 1
    else:
        unique_day_count[d] = 1
# Out:
# 100%|██████████| 318477/318477 [00:09<00:00, 35071.75it/s]
# 100%|██████████| 318477/318477 [00:08<00:00, 38131.35it/s]
# 100%|██████████| 318477/318477 [00:08<00:00, 37825.48it/s]
# 100%|██████████| 318477/318477 [00:08<00:00, 37528.52it/s]
# 100%|██████████| 318477/318477 [00:08<00:00, 36881.08it/s]

# %% [markdown]
# ### Visualise the number of job posts by month.

# %%
months = [10, 11, 12, 1, 2, 3]
month_counter = Counter(temp['Month'])
month_counts = [month_counter[m] for m in months]
month_labels = ['Oct', 'Nov', 'Dec', 'Jan', 'Feb', 'Mar']
explode = [0.1-x*0.005 for x in range(len(months))]
rgba = plt.cm.inferno_r(np.linspace(0, 0.7, len(months)))
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.barplot(x=month_labels, y=month_counts, palette=rgba, hue=month_labels, legend=False)
plt.title('Number of Job Posts by Month', size=14)
plt.xlabel('Month')
plt.ylabel('Average number of Job Posts')
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/1234864287.py:9: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(x=month_labels, y=month_counts, palette=rgba, hue=month_labels, legend=False)
# Text(0, 0.5, 'Average number of Job Posts')

# %% [markdown]
# ### Visualise the number of job posts by day of week.

# %%
weekdays_counts = temp['DayOfWeek'].value_counts()
weekdays = weekdays_counts.index
explode = [0.1-x*0.005 for x in range(7)]
rgba = plt.cm.inferno_r(np.linspace(0, 0.7, 7))
sns.set_style("whitegrid")
plt.figure(figsize=(10,5))
sns.barplot(x=weekdays, y=weekdays_counts, palette=rgba, hue=weekdays, legend=False)
plt.xticks(ticks=np.arange(len(weekdays)), labels=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']) 
plt.title('Job Posts by Day of Week', size=14)
plt.xlabel('Day of week')
plt.ylabel('Number of Job Posts')
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/3333928099.py:7: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(x=weekdays, y=weekdays_counts, palette=rgba, hue=weekdays, legend=False)
# Text(0, 0.5, 'Number of Job Posts')

# %% [markdown]
# ### Visualise the number of job posts by day of the month.

# %%
dayofmonth_counts = temp['DayOfMonth'].value_counts()


for day, count in dayofmonth_counts.items():
    dayofmonth_counts[day] = count / unique_day_count[day]

days = dayofmonth_counts.index

explode = [0.1-x*0.005 for x in range(30)]
rgba = plt.cm.inferno_r(np.linspace(0, 0.8, 31))
sns.set_style("whitegrid")
plt.figure(figsize=(15,5))
sns.barplot(x=days, y=dayofmonth_counts, palette=rgba, hue=days, legend=False) 
plt.title('Average Job Posts by Day of Month', size=14)
plt.xlabel('Day Of Month')
plt.ylabel('Number of Job Posts')
# Out:
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/4054527274.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '3356.3333333333335' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dayofmonth_counts[day] = count / unique_day_count[day]
# /var/folders/hn/l_q03tpx0kbfyhh2z32kfb2c0000gn/T/ipykernel_2093/4054527274.py:13: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.barplot(x=days, y=dayofmonth_counts, palette=rgba, hue=days, legend=False)
# Text(0, 0.5, 'Number of Job Posts')

# %% [markdown]
# ### Visualise trending of the job postings for the big cities.

# %%
df_location = df[df['Location'].isna()==False]
plt.figure(figsize=(20,8))

df_location_cnts = df_location.groupby('Location').count().reset_index()
df_location_top = df_location_cnts.sort_values(by=['Title'],ascending=False)['Location'].tolist()

for location in df_location_top[:5]:
    df_current = df[df['Location'] == location].groupby(['Date']).count().reset_index().sort_values(by=['Date'])
    df_current.set_index('Date',inplace=True)
    
    df_timeseries = df_current['Title'].rename('Count')

    plt.plot(df_timeseries,alpha=0.8, lw=2)

for location in df_location_top[5:]:
    df_current = df_location[df_location['Location'] == location].groupby(['Date']).count().reset_index().sort_values(by=['Date'])
    df_current.set_index('Date',inplace=True)
    
    df_timeseries = df_current['Title'].rename('Count')

    plt.plot(df_timeseries,alpha=0.4,c='lightgrey')
    
plt.legend(df_location_top[:5], title='Top 5 Cities', frameon=True)
plt.title('Job Posts by Location',size=14)
plt.xlabel('Date')
plt.ylabel('Number of Job Posts')
plt.show()

# %% [markdown]
# ### Based on the above charts, provide your observation about the number of job posts over time. Give your own conclusion.

# %% [markdown]
# Based on the chart showing the number of job posts over time for the top 5 cities in Australia (Sydney, Melbourne, Brisbane, Perth, and Adelaide), here are some observations and conclusions:
# ## Observations:
#
# ### Periodic Peaks:
# - There are clear, recurring spikes in the number of job posts approximately every two weeks.
# - These spikes are consistent across all cities, indicating a common pattern, possibly due to regular hiring cycles or job posting practices.
#
# ### Sydney and Melbourne Lead:
# - Sydney and Melbourne consistently have the highest number of job posts, often peaking between 2000 and 4000 job posts.
# - This trend suggests that these two cities are the major places for job opportunities in Australia.
#
# ### Relative Stability in Smaller Cities:
# - Brisbane, Perth, and Adelaide show fewer job posts compared to Sydney and Melbourne.
# - Despite the lower numbers, these cities still follow a similar pattern of periodic peaks.
#
# ### End-of-Year Decline:
# - There's a noticeable decline in job posts in the latter part of November and most of December.
# - This trend is likely due to the holiday season, where there is typically a slowdown in hiring activities.
#
# ### Mid-December Surge:
# - Towards mid-December, there's a sudden surge in job posts, especially in Sydney and Melbourne.
# - This could be attributed to companies trying to fill positions before the end of the calendar year or preparing for the new year.
#
# ### Overall Trends:
# - The number of job posts fluctuates significantly but shows a clear cyclical pattern.
# - The periodic spikes suggest that job posting activities are not evenly distributed throughout the months but instead follow a recurring schedule.
#
#
# ## Conclusion:
# The chart indicates a robust job market in Sydney and Melbourne, with regular hiring cycles that lead to periodic increases in job postings. Smaller cities like Brisbane, Perth, and Adelaide, while having fewer job posts, also show similar patterns. The data suggests that hiring activities slow down towards the end of the year but pick up again in mid-December, likely due to strategic hiring before the new year. Understanding these patterns can be beneficial for job seekers and employers in timing their job searches and recruitment processes.

# %% [markdown]
# ## 3. Forecasting and skill extractions. (2 points)

# %% [markdown]
# ### Using moving average for 7 days and 30 days to predict the number of job postings and visualise them in line chart. Which one creates a better prediction? Explain your choice.

# %%
df_timeseries_total = df.groupby(['Date']).count().reset_index().sort_values(by=['Date'])
df_timeseries_total.set_index('Date',inplace=True)

df_timeseries_total = df_timeseries_total[:151]

df_timeseries_total = df_timeseries_total['Title'].rename('Count')

moving_average_week = df_timeseries_total.rolling(7, min_periods=5)
moving_average_month = df_timeseries_total.rolling(30, min_periods=0)
plot_df = pd.DataFrame({'Count': df_timeseries_total, '7 Day Moving Average': moving_average_week.mean(), '30 Day Moving Average': moving_average_month.mean()})

plt.figure(figsize=(20,8))
plt.plot(plot_df['Count'],alpha=0.8, lw=2)
plt.plot(plot_df['7 Day Moving Average'],linestyle='--', lw=2)
plt.plot(plot_df['30 Day Moving Average'],linestyle='dotted', lw=3)
plt.legend(['Job Postings', '7 Day Moving Average', '30 Day Moving Average'], frameon=True)
plt.title('Job Posts Over Time',size=14)
plt.xlabel('Date')
plt.ylabel('Number of Job posts')
plt.show()

# %% [markdown]
# ### Analysis:
# - 7-Day Moving Average:
#
# The 7-day moving average (orange dashed line) reacts more quickly to changes in the data.
# It captures short-term fluctuations and provides a smoother line compared to the raw data (blue line).
# However, it might still be somewhat noisy and not as effective in highlighting longer-term trends.
#
# - 30-Day Moving Average:
#
# The 30-day moving average (green dashed line) is much smoother and less volatile than the 7-day moving average.
# It filters out short-term noise and is more effective in showing the long-term trend of job postings.
# This makes it easier to identify overall patterns and trends in the data over a longer period.
#
# ### Conclusion:
# The choice between the 7-day and 30-day moving average depends on the specific objective:
#
# For short-term predictions: If the goal is to understand and predict short-term fluctuations and trends, the 7-day moving average is more appropriate. It quickly adapts to changes and provides a better indication of recent variations in job postings.
#
# For long-term trends: If the goal is to understand the overall direction and long-term trends, the 30-day moving average is better. It smooths out short-term volatility and noise, making it easier to see the broader patterns and trends in the job postings.

# %% [markdown]
# ### Choose your favourite job sector/sub-sector, then use TF/IDF to extract important keywords. Visualise them in word cloud chart (hint: you can use the online tool https://wordart.com/create or similar websites)**.

# %%
# Create a new DataFrame with only the Information & Communication Technology sector
it_df = df[df['Classification'] == 'Information & Communication Technology']


#Deleting columns with missing descriptions
it_df = it_df.dropna(subset=['Requirement', 'FullDescription'])

#removing html tags from the description
it_df['FullDescription'] = it_df['FullDescription'].replace(r'<.*?>', '', regex=True)

#Tokenize
it_df['tokens_req'] = it_df.apply(lambda row: word_tokenize(row['Requirement']), axis=1)
it_df['tokens_desc'] = it_df.apply(lambda row: word_tokenize(row['FullDescription']), axis=1)

#Remove punctuation
it_df['alpha_req'] = it_df['tokens_req'].apply(lambda x: [word for word in x if word.isalpha()])
it_df['alpha_desc'] = it_df['tokens_desc'].apply(lambda x: [word for word in x if word.isalpha()])

#Remove stop words
stop_words = stopwords.words('english')
it_df['stop_req'] = it_df['alpha_req'].apply(lambda x: [word for word in x if word not in stop_words])
it_df['stop_desc'] = it_df['alpha_desc'].apply(lambda x: [word for word in x if word not in stop_words])

#stemming
stemmer = PorterStemmer()
it_df['stem_req'] = it_df['stop_req'].apply(lambda x: [stemmer.stem(word) for word in x])
it_df['stem_desc'] = it_df['stop_desc'].apply(lambda x: [stemmer.stem(word) for word in x])

# %%
vectorizer = TfidfVectorizer(lowercase=False, analyzer=lambda x: x)
td_idf = vectorizer.fit_transform(it_df['stem_req']).toarray()
td_idf = pd.DataFrame(data=td_idf, columns=vectorizer.get_feature_names_out())

print("Highest words Requirements: ", td_idf.max(axis=0).sort_values(ascending=False).head(20))
# Out:
# Highest words Requirements:  month           1.000000
# tibco           1.000000
# develop         1.000000
# bau             1.000000
# avocado         1.000000
# c               1.000000
# interview       1.000000
# start           1.000000
# look            1.000000
# till            1.000000
# analyst         1.000000
# freelanc        0.953203
# sitecor         0.942280
# synolog         0.937383
# cryptographi    0.932595
# etl             0.930141
# skype           0.929912
# android         0.927800
# princip         0.927519
# week            0.924453
# dtype: float64

# %% [markdown]
# ![image](req_words.png)

# %%
vectorizer = TfidfVectorizer(lowercase=False, analyzer=lambda x: x)
td_idf = vectorizer.fit_transform(it_df['stem_desc']).toarray()
td_idf = pd.DataFrame(data=td_idf, columns=vectorizer.get_feature_names_out())

print("Highest words Full Description: ", td_idf.max(axis=0).sort_values(ascending=False).head(20))
# Out:
# Highest words Full Description:  nbsp             0.990758
# siam             0.940980
# anaplan          0.934772
# comptel          0.919659
# gt               0.906807
# bizflow          0.898918
# ediscoveri       0.894486
# servicenow       0.885553
# sa               0.880008
# tririga          0.878111
# hpc              0.872586
# qlikview         0.867047
# test             0.866885
# temeno           0.865959
# ascend           0.865954
# e                0.865934
# microstrategi    0.863186
# amadeu           0.858740
# shopifi          0.858225
# qlik             0.857445
# dtype: float64

# %% [markdown]
# ![image](desc_words.png)

# %% [markdown]
# # Part 4 - Discussion. (4 Marks)

# %% [markdown]
# ### Scenario 1: Tom, a grade 12 student in Brisbane, has good results in all of the subjects in his school. He is finding a major in the University which can guarantee a job in his state (Queensland) with a good income (>=80K) in the future. Based on the current job market dataset, which major and the related subjects do you recommend him? Explain your choice.*** ( Max 750 words)

# %%
classification_brisbane = df_brisbane.groupby('Classification').agg(
    average_salary=('AverageSalary', 'mean'),
).reset_index()

classification_brisbane.sort_values(by='average_salary',ascending=False, inplace=True)

plt.figure(figsize=(10,10))
sns.barplot(
    data=classification_brisbane[:10], 
    x='average_salary',
    y='Classification',
    color= '#377ead', 
    palette= 'inferno',
    hue='Classification',
    legend=False
)
plt.xlabel('Average Salary ($)')
plt.title('Average Salary by Classification')
plt.show()

# %% [markdown]
# Based on the average salary data, the top classifications with the highest average salaries in Queensland are:
#
# * CEO & General Management
# * Information & Communication Technology (ICT)
# * Mining, Resources & Energy
# * Consulting & Strategy
# * Healthcare & Medical
#
# To ensure Tom has a good chance of securing a job with a salary of at least $80K, we will focus on majors related to these high-paying fields. Here’s a breakdown of each of these fields and the relevant subjects or majors:
#
# 1. CEO & General Management</br>
# While this field offers the highest average salary, it is typically not a direct career path from a specific undergraduate major. Success in this field often requires extensive experience and a combination of business acumen, leadership skills, and advanced education (e.g., MBA).
#
# 2. Information & Communication Technology (ICT)</br>
# ICT is a rapidly growing field with high demand for skilled professionals. Relevant majors include:
#
# - Computer Science
# - Information Technology
# - Software Engineering
# - Data Science
# - Cybersecurity
#
# 3. Mining, Resources & Energy</br>
# Queensland has a significant mining and energy sector. Relevant majors include:
#
# - Mining Engineering
# - Environmental Engineering
# - Geology
# - Petroleum Engineering
# - Renewable Energy Engineering
#
# 4. Consulting & Strategy</br>
# This field often requires strong analytical and business skills. Relevant majors include:
#
# - Business Administration
# - Economics
# - Management
# - Finance
# - Marketing
#
# 5. Healthcare & Medical</br>
# The healthcare sector is always in demand and offers various high-paying roles. Relevant majors include:
#
# - Medicine
# - Nursing
# - Pharmacy
# - Medical Science
# - Physiotherapy
# - Public Health
#
# Given Tom’s goal of securing a high-paying job, We recommend he consider majors in Information & Communication Technology (ICT) or Mining, Resources & Energy due to the combination of high average salaries and strong job prospects in Queensland.
#
# The bar chart above highlights the top 10 job classifications by average salary in Queensland. Notably, Information & Communication Technology (ICT) and Mining, Resources & Energy stand out as promising fields with high average salaries.
#
# ### Recommendation
# #### Information & Communication Technology (ICT)
#
# - Why ICT?</br>
# High demand for ICT professionals.</br>
# Diverse career opportunities in software development, data analysis, cybersecurity, and more.</br>
# Significant technological growth and innovation.</br>
#
# - Relevant Subjects:
# Computer Science,
# Information Technology,
# Software Engineering,
# Data Science,
# Cybersecurity
#
# #### Mining, Resources & Energy
#
# - Why Mining, Resources & Energy?</br>
# Queensland's strong mining sector.</br>
# High average salaries and job security.</br>
# Opportunities in sustainable and renewable energy sectors.</br>
#
# - Relevant Subjects:
# Mining Engineering,
# Environmental Engineering,
# Geology,
# Petroleum Engineering,
# Renewable Energy Engineering
#
# By pursuing a major in one of these fields, Tom can position himself for a successful and well-compensated career in Queensland.

# %% [markdown]
# ### Scenario 2: To gain a better reputation, Griffith University wants to attract more students by enhancing the employability of the graduates. As a data analyst, you need to give the recommendation for the management board for the changing of the admission numbers in each major. Which majors should be extended, and which majors should be reduced (Assume that we only need to use job market data, regardless of other factors such as social impact, economic impact, etc. )? Justify your recommendation.*** ( Max 750 words)

# %%
classification = df.groupby('Classification').agg(
    average_salary=('AverageSalary', 'mean'),
).reset_index()

classification.sort_values(by='average_salary', ascending=False, inplace=True)

plt.figure(figsize=(10,10))
sns.barplot(
    data=classification, 
    x='average_salary',
    y='Classification',
    color= '#377ead', 
    palette= 'inferno',
    hue='Classification',
    legend=False
)
plt.xlabel('Average Salary ($)')
plt.title('Average Salary by Classification')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To provide Griffith University with recommendations for adjusting the admission numbers in each major, we will analyze job market data to identify which fields have the highest demand for graduates and offer the best employment prospects. This analysis will focus on salary information and job availability in various sectors.
#
#
# ### Recommendations
#
# - Extend Admissions:
#
# Fields with High Average Salaries: Attract more students to high-paying fields such as Information Technology, Engineering, and Legal.
# Fields with High Job Demand: Increase admissions in fields with many job postings such as Healthcare, Trades, and Hospitality.
#
# - Reduce Admissions:
# Fields with Lower Demand and Salary: Consider reducing admissions in fields with lower salaries and fewer job postings to align with market demand.
#
# ###  Justification
# - Information Technology: High average salaries and significant job demand indicate robust employability.
# - Healthcare: Strong demand for healthcare professionals with competitive salaries.
# - Engineering: High average salaries and job opportunities, especially in specialized areas.
#
# Fields with lower average salaries and fewer job opportunities should be reduced to better align with the job market and improve graduate employability.
#
# By strategically adjusting admissions based on these insights, Griffith University can enhance the employability of its graduates, and therefore attracting more students and improving its reputation.
#
#
# ### Majors to Extend
#
# - Information & Communication Technology (ICT)
# Justification: ICT has the second-highest average salary ($180,000 approximately) and a very high number of job postings (22,000 approximately). The demand for ICT professionals is robust, driven by the growing tech industry.
#
#
# - Engineering
# Justification: Engineering offers a high average salary ($120,000 approximately) and a significant number of job opportunities (6,000 approximately). Fields like civil, mechanical, and electrical engineering are critical in various industries.
#
# - Healthcare & Medical
# Justification: With an average salary of $120,000 approximately and 17,000 approximately job postings, healthcare is a vital and expanding field. The demand for healthcare professionals, especially in nursing and allied health, continues to rise.
#
# ### Majors to Reduce
#
# - Hospitality & Tourism
# Justification: Despite a high number of job postings the average salary in this sector is relatively low ($40,000 approximately). The hospitality industry often includes lower-paying, entry-level jobs.
#
# - Retail & Consumer Products
# Justification: The average salary in this sector is low ($45,000 approximately), despite having 8,000 job postings. Jobs in retail often involve lower wages and higher turnover.
#
#
# - Call Centre & Customer Service
# Justification: With an average salary of $48,000 and 3,000 approximately job postings, this sector offers limited career advancement and lower pay compared to others.
#
#
# ### Conclusion
#
# By strategically adjusting admissions based on job market data, Griffith University can enhance the employability of its graduates.
# Increasing admissions in high-demand and high-salary fields such as ICT, engineering, and healthcare will attract more students and improve the university's
# reputation. On the other hand, reducing admissions in lower-paying fields will ensure resources are focused on areas that offer better career prospects for graduates.
